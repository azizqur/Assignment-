# %% [markdown]
# ## ASSIGNMENT NO 1

# %% [markdown]
# - LAB TASK 1

# %%
#Print Your Name with your Father name and Date of birth using suitable escape sequence character

print("\tName: Aziz Rehman")
print("\tFather Name: Irshad Ali")
print("\tDOB: 24/12/2005")
# Out:
# 	Name: Aziz Rehman
# 	Father Name: Irshad Ali
# 	DOB: 24/12/2005

# %% [markdown]
# - LAB TASK 2

# %%
#Write your small bio using variables and print it using print function

print("My bio")
print("-------")
print("Name: Aziz Rehman")
print("Father Name: Irshad Ali")
print("age = 20")
print("Education: Computer Science")
print("Hobby: Coding and Gaming")

print("My bio")
print("-------")
print("Name: Aziz Rehman")
print("Father Name: Irshad Ali")
print("age = 20")
print("Education: Computer Science")
print("Hobby: Coding and Gaming")
# Out:
# My bio
# -------
# Name: Aziz Rehman
# Father Name: Irshad Ali
# age = 20
# Education: Computer Science
# Hobby: Coding and Gaming

# %% [markdown]
# # LAB TASK 3

# %%
#Write a program in which use all the operators we can use in Python

a = 10
b = 20

#Arithmatic

print(a+b,a-b,a*b,a/b,a%b)

#Relational Operator

print(a>b,a<b,a>=b,a<=b,a==b,a!=b)

#Logical Operator

print(a > 0 and b > 0) #AND Operator
print(a < 0 or b < 0) #OR Operator
print(~a) #NOT Operator

#Bit wise Operator

print( a & b) #AND Operator
print(a | b) #OR Operator
print(a ^ b) #XOR Operator
print(~a) #NOT Operator
print(a << b) 
print(a >> b)

#Assignment Operator

a += b
print(a)

a -= b
print(a)

a = b
print(a)

a *= b
print(b)

a %=b
print (b)
# Out:
# 30 -10 200 0.5 10
# False True False True False True
# True
# False
# -11
# 0
# 30
# 30
# -11
# 10485760
# 0
# 30
# 10
# 20
# 20
# 20

# %% [markdown]
# # LAB TASK 4

# %%
#Completes the following steps of small task:
#Mention Marks of English , Islamiat and Maths out of 100 in 3 different variables
#Mention Variable of Total Marks and assign 300 to it
#Calculate Percentage

english = 80
islamiat = 90
maths = 75

total = 300
print("Total:", total)
obtained = english + islamiat + maths
print("Obtain:", obtained )
percantage = (obtained / total) *100

print("Percantage:", percantage )
# Out:
# Total: 300
# Obtain: 245
# Percantage: 81.66666666666667
